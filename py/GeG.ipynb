# %% [markdown]
# #### You are given a String S, you need to print its characters at even indices(index starts at 0).
# Input: s = "Geeks"
# Output: Ges
# Explanation: The even indices characters are printed.
# CODE:
# def utility(s):
#     #code here
#   print(s[::2],end='')

# %% [markdown]
# #### Given a number x, the task is to print the numbers from x to 0 in decreasing order in a single line.
#
# Example:
#
# Input: x = 3
# Output: 3 2 1 0
# Explanation: Numbers in decreasing order from 3 are 3 2 1 0.
# code:
# for x in range(x,-1):
#         print(x[::-1])

# %%
print(9//2)
# Out:
# 4

# %%
print(5%20)
# Out:
# 5

# %%
print((4+5)*5**(4-2));
# Out:
# 225

# %%
str = "GFG"
print(not (not(str and "")))
# Out:
# False

# %%
s = "gfg"
print("G" in s)
# Out:
# False

# %%
s = "gfg"
print(("g" or "") in s)
# Out:
# True

# %%
s = "gfg"
print(not ("g" or "") not in s)
# Out:
# True

# %%
print(oct(23))
# Out:
# 0o27

# %%
print(oct(23)+oct(23))
# Out:
# 0o270o27

# %%
print(~(~2))
# Out:
# 2

# %%
def sayHello():
  print('Hello World!')
  sayHello()
sayHello()
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# ...

# %%
def display(b, n):
  while n > 0:
    print(b,end="")
    n=n-1
display('z',3)
# Out:
# zzz

# %%
x = 50
def func():
    global x
    print('x is', x)
    x = 2
    print('Changed global x to', x)
    func()
    print('Value of x is', x)  # no output because, Since the function is not called in the main block, Hence the function will never get executed.
#Therefore, the answer will be no output.

# %%
print("chalini")
# Out:
# chalini

# %%
def alphabets(c1,c2):
     for ch in range(chr(int1), chr(int2) + 1):
         print(ord(ch), end=" ")

# %%
print('a'+'bc')
# Out:
# abc

# %%
'abcd'[2:]
# Out:
# 'cd'

# %%
e=''
e[3]='s'
print e
# Out:
#   Cell In[32], line 3
#     print e
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
max('geeksforgeeks')
# Out:
# 's'

# %%
e='hello'
e.count('l')
# Out:
# 2

# %%
print(chr(ord('b')+1))
# Out:
# c

# %%
print('geeks'.upper())
# Out:
# GEEKS

# %%
print('geeksforgeeks'.lstrip('geeks'))
# Out:
# forgeeks

# %%
print('geeksforgeeks'.split('ee'))
# Out:
# ['g', 'ksforg', 'ks']

# %%
print('geeksforgeeks'.split('ee',1))
# Out:
# ['g', 'ksforgeeks']

# %%
print("geeksforgeeks".endswith("geeks", 1,13 ))
# Out:
# True

# %%
list1 = [0.5 * x for x in range(0, 4)]
list1
# Out:
# [0.0, 0.5, 1.0, 1.5]

# %%
e=[3, 4, 5, 20, 5, 25, 1, 3]
e1=e.pop()
e1
# Out:
# 3

# %%
my_string = "geeks"
k = [(i.upper(), len(i)) for i in my_string]
print(k)
# Out:
# [('G', 1), ('E', 1), ('E', 1), ('K', 1), ('S', 1)]

# %%
print([i.lower() for i in "GFG"])
# Out:
# ['g', 'f', 'g']

# %%
s=["GEEKS", "FOR", "GEEKS"]
k=[(w.lower(), len(w)) for w in s]
print(k)
# Out:
# [('geeks', 5), ('for', 3), ('geeks', 5)]

# %%
t=32.00
[round((x-32)*5/9) for x in t]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 t=32.00
# ----> 2 [round((x-32)*5/9) for x in t]
#
# TypeError: 'float' object is not iterable

# %%
a=(2,3,4)
print(sum(a,3))
# Out:
# 12

# %%
a={4,5,6}
b={2,8,6}
print(a-b)
# Out:
# {4, 5}

# %%
s=set()
print (type(s))
# Out:
# <class 'set'>
